# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**與**地球大氣層**互相作用所產生的物理現象，這個現象被稱為**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。這些光以「波」的形式傳播，不同顏色的光有不同的**波長**：
# *   **紅色、黃色光**的波長較**長**。
# *   **藍色、紫色光**的波長較**短**。
#
# ### 2. 大氣層的「阻擋」
# 地球周圍包覆著厚厚的大氣層，裡面充滿了氣體分子（主要是氮氣和氧氣）以及微小的塵埃。
# 當太陽光穿過大氣層時，會與這些微小的氣體分子相撞：
# *   波長較長的**紅光、黃光**穿透力很強，能夠直接穿過大氣分子，直達地面。
# *   波長較短的**藍光**，很容易被這些微小的氣體分子撞擊，並向四面八方**散射（彈開）**。這些被散射的藍光充滿了整個天空，當我們抬頭看時，就會覺得天空是藍色的。
#
# ---
#
# ### 常見疑問：為什麼天空不是「紫色」的？
# 既然紫色光的波長比藍光更短，被散射得更厲害，那天空為什麼不是紫色的？
#
# 這有兩個主要原因：
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的強度本來就比紫光強很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有感知顏色的細胞，我們對「藍色」的敏感度遠高於「紫色」。所以，即使天空中有一些紫光，我們的大腦還是會自動把它過濾並解讀為藍色。
#
# ---
#
# ### 順帶一提：為什麼夕陽是紅色的？
# 傍晚太陽下山時，陽光是斜射過來的，必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這個漫長的過程中，藍光在半路就已經被散射殆盡了，只剩下穿透力最強的**紅光和橙光**能夠到達我們的眼睛，所以夕陽看起來就是美麗的紅黃色。
