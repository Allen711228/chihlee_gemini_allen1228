# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**、**地球大氣層**以及一種叫做**「瑞利散射」（Rayleigh scattering）**的物理現象共同作用的結果。
#
# 我們可以把這個過程拆解成以下三個簡單的步驟來理解：
#
# ### 1. 太陽光是由七彩組成的
# 太陽光看似是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的（就像彩虹一樣）。這些光以「波」的形式傳播：
# *   **紅光、橙光**的波長較**長**。
# *   **藍光、紫光**的波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 當太陽光穿過地球的大氣層時，會遇到大氣中的氣體分子（主要是氮氣和氧氣）以及微小的塵埃。
# *   波長較**長**的光（如紅光、黃光）像巨浪一樣，能輕易繞過這些微小的氣體分子，直接穿透大氣層直達地面。
# *   波長較**短**的光（如藍光、紫光）就像小波浪，撞到這些微小的氣體分子後，就會向四面八方**散射**開來。這種現象就叫做「瑞利散射」。這些被散射的藍光充滿了整個天空，當我們抬頭看時，就會覺得天空是藍色的。
#
# ### 3. 為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短、散射得更厲害，為什麼天空看起來是藍色而不是紫色呢？這有兩個主要原因：
# 1.  **太陽光本身的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類視網膜上的感光細胞對「藍色」比對「紫色」敏感得多。因此，即使天空中有紫光，我們的眼睛也主要只接收到藍色。
#
# ---
#
# ### 補充：那為什麼傍晚的夕陽是紅色的？
# 黃昏時，太陽角度很低，陽光需要穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這個過程中，大部分的藍光在半路就已經被散射光了，只剩下波長最長、穿透力最強的**紅光和橙光**能夠到達我們的眼睛，所以夕陽看起來就是美麗的橘紅色。
